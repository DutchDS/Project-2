# %%
import pandas as pd
from sqlalchemy import create_engine
import datetime
import os

# %%
def create_big_df(filename):
#     print("hello")
    df_big = pd.DataFrame()
#     filename = "static/data/df_2020-01-29.csv"
    df_data = pd.read_csv(filename)
    df_data.head()
    df_big = df_big.append(df_data)
#     print(df_big)

# %%
def save_to_database(df_big):
    connection_string = "postgres:postgres@localhost:5432/corona_db"
    engine = create_engine(f'postgresql://{connection_string}')

    df_big.to_sql(name='daily_stats', con=engine, if_exists='append', index=False)

# %%
def save_world_to_database(df_world):
    connection_string = "postgres:postgres@localhost:5432/corona_db"
    engine = create_engine(f'postgresql://{connection_string}')

    df_world.to_sql(name='daily_stats_world', con=engine, if_exists='append', index=False)

# %%
df_big = pd.DataFrame()
# For later. Loop through all the files created
for file in os.listdir("static/data"):
    if file.endswith(".csv"):
         # print(os.path.join(directory, filename))
        print("Now Processing: " + "static/data/" + file)
        date = file[3:13]
        filename = "static/data/" + file
#         print(filename)
#     filename = "static/data/df_2020-01-29.csv"
        df_data = pd.read_csv(filename)
#         df_data.head()
        df_big = df_big.append(df_data)
#         create_big_df("static/data/" + filename)
        continue
    else:
        continue
        
df_big.head()
df_big.to_csv("static/out/out.csv", encoding='utf-8')
# Out:
# Now Processing: static/data/df_2020-01-26.csv
# Now Processing: static/data/df_2020-01-27.csv
# Now Processing: static/data/df_2020-01-28.csv
# Now Processing: static/data/df_2020-01-29.csv
# Now Processing: static/data/df_2020-01-30.csv
# Now Processing: static/data/df_2020-01-31.csv
# Now Processing: static/data/df_2020-02-01.csv
# Now Processing: static/data/df_2020-02-02.csv
# Now Processing: static/data/df_2020-02-03.csv
# Now Processing: static/data/df_2020-02-04.csv
# Now Processing: static/data/df_2020-02-05.csv
# Now Processing: static/data/df_2020-02-06.csv
# Now Processing: static/data/df_2020-02-07.csv
# Now Processing: static/data/df_2020-02-08.csv
# Now Processing: static/data/df_2020-02-09.csv
# Now Processing: static/data/df_2020-02-10.csv
# Now Processing: static/data/df_2020-02-11.csv
# Now Processing: static/data/df_2020-02-12.csv
# Now Processing: static/data/df_2020-02-13.csv
# Now Processing: static/data/df_2020-02-14.csv
# Now Processing: static/data/df_2020-02-15.csv
# Now Processing: static/data/df_2020-02-16.csv
# Now Processing: static/data/df_2020-02-17.csv
# Now Processing: static/data/df_2020-02-18.csv
# Now Processing: static/data/df_2020-02-19.csv
# Now Processing: static/data/df_2020-02-20.csv
# Now Processing: static/data/df_2020-02-21.csv
# Now Processing: static/data/df_2020-02-22.csv
# Now Processing: static/data/df_2020-02-23.csv
# Now Processing: static/data/df_2020-02-24.csv

# %%
df_big.count()
df_big.rename(columns = {'provinceName':'province_name', 
                         'provinceShortName':'province_short', 
                         'confirmedCount':'conf_count', 
                         'suspectedCount': 'susp_count', 
                         'curedCount':'cured_count',
                         'deadCount':'dead_count'}, inplace = True) 
save_to_database(df_big)

# %%
# Start here to process the world data (only call save_world_to_database)
url_world = "static/world_data/df_world_all.csv"
df_world = pd.read_csv(url_world)
df_world.head()
save_world_to_database(df_world)

# %%
query_str = open('static/sql/test_query.sql')
query_text = ""
for text in query_str:
    query_text = query_text + text

connection_string = "postgres:postgres@localhost:5432/corona_db"
engine = create_engine(f'postgresql://{connection_string}')    
print(query_text)
df_query = pd.read_sql_query(query_text, con=engine)

df_query
# Out:
# select date,
# 	sum(conf_count) confirmed,
# 	sum(susp_count) suspected,
# 	sum(cured_count) cured,
# 	sum(dead_count) dead
# from daily_stats
# group by date
# order by date
#           date  confirmed  suspected  cured  dead
# 0   2020-01-26       1812          0     49    55
# 1   2020-01-27       2081          0     49    56
# 2   2020-01-28       2858          0     56    82
# 3   2020-01-29       4633          0     73   106
# 4   2020-01-30       6095          1    120   133
# 5   2020-01-31       8150          0    135   171
# 6   2020-02-01      11230          0     70   258
# 7   2020-02-02      13831          0    322   304
# 8   2020-02-03      14525          1    435   305
# 9   2020-02-04      19690          0    527   425
# 10  2020-02-05      20540          2    718   426
# 11  2020-02-06      27434          0   1115   563
# 12  2020-02-07      31180        166   1537   637
# 13  2020-02-08      34293          0   2004   719
# 14  2020-02-09      36895      23710   2599   808
# 15  2020-02-10      39824          0   3216   905
# 16  2020-02-11      42718          0   4060  1017
# 17  2020-02-12      44742          0   4778  1114
# 18  2020-02-13      44767          0   5066  1117
# 19  2020-02-14      63935          0   6809  1381
# 20  2020-02-15      66413          0   7987  1521
# 21  2020-02-16      68586          0   9550  1666
# 22  2020-02-17      70639          0  11049  1772
# 23  2020-02-18      72531          0  12838  1871
# 24  2020-02-19      74280          0  14571  2009
# 25  2020-02-20      74675          0  16254  2121
# 26  2020-02-21      74690          0  16749  2124
# 27  2020-02-22      75576          0  18704  2239
# 28  2020-02-23      76397          0  21089  2348
# 29  2020-02-24      77050          0  23189  2446

# %%
# query_str = open('static/sql/test_world.sql')
query_str = open('static/sql/world_top_10.sql')
query_text = ""
for text in query_str:
    query_text = query_text + text

connection_string = "postgres:postgres@localhost:5432/corona_db"
engine = create_engine(f'postgresql://{connection_string}')    
print(query_text)
df_query = pd.read_sql_query(query_text, con=engine)

df_query
# Out:
# select date,
# 	country,
# 	sum(conf_count) confirmed,
# 	sum(cured_count) cured,
# 	sum(dead_count) dead
# from daily_stats_world
# group by date, country
# order by date
#             date               country  confirmed  cured  dead
# 0     2020-01-22  United Arab Emirates          0      0     0
# 1     2020-01-22                 Italy          0      0     0
# 2     2020-01-22               Romania          0      0     0
# 3     2020-01-22                Israel          0      0     0
# 4     2020-01-22                 Spain          0      0     0
# ...          ...                   ...        ...    ...   ...
# 1759  2020-02-26                  Iran        139     49    19
# 1760  2020-02-26                Russia          2      2     0
# 1761  2020-02-26                 Egypt          1      0     0
# 1762  2020-02-26              Malaysia         22     18     0
# 1763  2020-02-26                 India          3      3     0
#
# [1764 rows x 5 columns]
